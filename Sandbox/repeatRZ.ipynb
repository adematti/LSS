# %%
from __future__ import division, print_function
import sys, os, glob, time, warnings, gc
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table, vstack, hstack, join
import fitsio

# %%
params = {'legend.fontsize': 'x-large',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large',
         'figure.facecolor':'w'} 
plt.rcParams.update(params)

# %%
tileid_list = [80607, 80609, 80620]

# %%
#some criteria
fail_threshold = 0.0033
deep_dchi2 = 100
mindepth = 120

# %%
for td in tileid_list:
    
    print('Tile {}'.format(td))
    
    #f = fitsio.read('/project/projectdirs/desi/users/ajross/catalogs/SV/redshift_comps/testRP/'+str(td)+'_LRGzinfo.fits')
    f = fitsio.read('/project/projectdirs/desi/users/ajross/catalogs/SV/redshift_comps/test/'+str(td)+'_LRGzinfo.fits') #fitsio *much* faster than using Table here
    deep = f[f['subset']=='deep'] 
    min_depth = np.max(deep['R_DEPTH'])/2
    print(len(f),len(deep),min_depth)
    
    #get list of truez in appropriate rows, matching Rongpu's definition for criteria required to allow truth determination
    #rows without truth have z==0
    mzl = np.zeros(len(f))
    tids = np.unique(f['TARGETID'])
    for iid in tids:
        sf = f['TARGETID'] == iid
        fi = f[sf]
        fd = fi[fi['subset']=='deep']
        mask = fd['FIBERSTATUS']==0 # Remove FIBERSTATUS!=0 fibers
        mask &= fd['ZWARN'] & 2**9==0 # Remove "no data" fibers
        mask &= fd['ZWARN']==0
        mask &= fd['R_DEPTH'] > min_depth
        mask &= fd['DELTACHI2'] > deep_dchi2
        if len(fd[mask]) > 0:
            mzl[sf] = fd['Z']
    
    w = mzl != 0
    print(len(mzl[w]))
    tf = Table(f)
    tf['Z_TRUTH'] = mzl
    masknight = tf['subset'] != 'deep'
    masknight &= tf['subset'] != 'all'
    masknight &= tf['Z_TRUTH'] != 0
    masknight &= tf['FIBERSTATUS']==0
    masknight &= tf['ZWARN'] & 2**9==0
    tcomp = tf[masknight]
    dz = tcomp['Z'] - tcomp['Z_TRUTH']
    bz = abs(dz) > fail_threshold
    bzz = bz & (tcomp['ZWARN'] != 0)
    print('number, fraction of failures, fraction of failures with zwarn==0')
    print(len(tcomp),len(tcomp[bz])/len(tcomp),len(tcomp[bzz])/len(tcomp))
    rvals = np.unique(tcomp['R_DEPTH'])
    ff = []
    rv = []
    nb = []
    nt = []
    for rval in rvals:
        ds = tcomp[tcomp['R_DEPTH']==rval]
        dz = ds['Z'] - ds['Z_TRUTH']
        bz = abs(dz) > fail_threshold
        if len(ds) > 30 and rval > mindepth:
            ff.append(len(ds[bz])/len(ds))
            nb.append(len(ds[bz]))
            nt.append(len(ds))
            rv.append(rval)
    nt = np.array(nt)
    nb = np.array(nb)
    err = ((nt-nb)*(1.-(nt-nb)/nt))**.5/nt #binomial error formula, needs double-check
    plt.errorbar(rv,ff,err,fmt='.',label=td)

plt.legend()
plt.grid(alpha=0.5)
plt.xlabel('R_DEPTH effective exposure time')
plt.ylabel('failure fraction')
plt.show()
# Out:
# Tile 80607
# 13266 1922 6097.749969482422
# 10388
# number, fraction of failures, fraction of failures with zwarn==0
# 7163 0.05891386290660338 0.029736144073712133
# Tile 80609
# 12750 2125 4106.550003051758
# 9606
# number, fraction of failures, fraction of failures with zwarn==0
# 6341 0.04857278031856174 0.02554802081690585
# Tile 80620
# 11890 2049 4787.799987792969
# 8640
# number, fraction of failures, fraction of failures with zwarn==0
# 5426 0.06376704754883893 0.03133063029856248

# %%
f = Table.read('/project/projectdirs/desi/users/ajross/catalogs/SV/redshift_comps/testRP/'+str(td)+'_LRGzinfo.fits')

# %%
for col in f.columns:
    print(col)
# Out:
# TARGETID
# CHI2_1
# COEFF_1
# Z_1
# ZERR_1
# ZWARN_1
# NPIXELS_1
# SPECTYPE_1
# SUBTYPE_1
# NCOEFF_1
# DELTACHI2_1
# NUMEXP_1
# NUMTILE_1
# PETAL_LOC_1
# DEVICE_LOC_1
# LOCATION_1
# FIBER_1
# FIBERSTATUS_1
# TARGET_RA_1
# TARGET_DEC_1
# PMRA_1
# PMDEC_1
# REF_EPOCH_1
# LAMBDA_REF_1
# FA_TARGET_1
# FA_TYPE_1
# OBJTYPE_1
# FIBERASSIGN_X_1
# FIBERASSIGN_Y_1
# NUMTARGET_1
# PRIORITY_1
# SUBPRIORITY_1
# OBSCONDITIONS_1
# MORPHTYPE_1
# FLUX_G_1
# FLUX_R_1
# FLUX_Z_1
# FLUX_IVAR_G_1
# FLUX_IVAR_R_1
# FLUX_IVAR_Z_1
# REF_ID_1
# REF_CAT_1
# GAIA_PHOT_G_MEAN_MAG_1
# GAIA_PHOT_BP_MEAN_MAG_1
# GAIA_PHOT_RP_MEAN_MAG_1
# PARALLAX_1
# EBV_1
# FLUX_W1_1
# FLUX_W2_1
# FIBERFLUX_G_1
# FIBERFLUX_R_1
# FIBERFLUX_Z_1
# FIBERTOTFLUX_G_1
# FIBERTOTFLUX_R_1
# FIBERTOTFLUX_Z_1
# MASKBITS_1
# SERSIC_1
# SHAPE_R_1
# SHAPE_E1_1
# SHAPE_E2_1
# PHOTSYS_1
# SV1_DESI_TARGET_1
# SV1_BGS_TARGET_1
# SV1_MWS_TARGET_1
# PRIORITY_INIT_1
# NUMOBS_INIT_1
# RELEASE_1
# BRICKID_1
# BRICKNAME_1
# BRICK_OBJID_1
# BLOBDIST_1
# FIBERFLUX_IVAR_G_1
# FIBERFLUX_IVAR_R_1
# FIBERFLUX_IVAR_Z_1
# DESI_TARGET_1
# BGS_TARGET_1
# MWS_TARGET_1
# HPXPIXEL_1
# NUM_ITER_1
# FIBER_X_1
# FIBER_Y_1
# MEAN_DELTA_X_1
# MEAN_DELTA_Y_1
# FIBER_RA_1
# FIBER_DEC_1
# COADD_NUMEXP_1
# RMS_DELTA_X_1
# RMS_DELTA_Y_1
# FIRST_FIBER_1
# LAST_FIBER_1
# NUM_FIBER_1
# B_DEPTH_1
# R_DEPTH_1
# Z_DEPTH_1
# subset_1
# CHI2_2
# COEFF_2
# Z_2
# ZERR_2
# ZWARN_2
# NPIXELS_2
# SPECTYPE_2
# SUBTYPE_2
# NCOEFF_2
# DELTACHI2_2
# NUMEXP_2
# NUMTILE_2
# PETAL_LOC_2
# DEVICE_LOC_2
# LOCATION_2
# FIBER_2
# FIBERSTATUS_2
# TARGET_RA_2
# TARGET_DEC_2
# PMRA_2
# PMDEC_2
# REF_EPOCH_2
# LAMBDA_REF_2
# FA_TARGET_2
# FA_TYPE_2
# OBJTYPE_2
# FIBERASSIGN_X_2
# FIBERASSIGN_Y_2
# NUMTARGET_2
# PRIORITY_2
# SUBPRIORITY_2
# OBSCONDITIONS_2
# MORPHTYPE_2
# FLUX_G_2
# FLUX_R_2
# FLUX_Z_2
# FLUX_IVAR_G_2
# FLUX_IVAR_R_2
# FLUX_IVAR_Z_2
# REF_ID_2
# REF_CAT_2
# GAIA_PHOT_G_MEAN_MAG_2
# GAIA_PHOT_BP_MEAN_MAG_2
# GAIA_PHOT_RP_MEAN_MAG_2
# PARALLAX_2
# EBV_2
# FLUX_W1_2
# FLUX_W2_2
# FIBERFLUX_G_2
# FIBERFLUX_R_2
# FIBERFLUX_Z_2
# FIBERTOTFLUX_G_2
# FIBERTOTFLUX_R_2
# FIBERTOTFLUX_Z_2
# MASKBITS_2
# SERSIC_2
# SHAPE_R_2
# SHAPE_E1_2
# SHAPE_E2_2
# PHOTSYS_2
# SV1_DESI_TARGET_2
# SV1_BGS_TARGET_2
# SV1_MWS_TARGET_2
# PRIORITY_INIT_2
# NUMOBS_INIT_2
# RELEASE_2
# BRICKID_2
# BRICKNAME_2
# BRICK_OBJID_2
# BLOBDIST_2
# FIBERFLUX_IVAR_G_2
# FIBERFLUX_IVAR_R_2
# FIBERFLUX_IVAR_Z_2
# DESI_TARGET_2
# BGS_TARGET_2
# MWS_TARGET_2
# HPXPIXEL_2
# NUM_ITER_2
# FIBER_X_2
# FIBER_Y_2
# MEAN_DELTA_X_2
# MEAN_DELTA_Y_2
# FIBER_RA_2
# FIBER_DEC_2
# NIGHT
# EXPID
# MJD
# TILEID
# COADD_NUMEXP_2
# RMS_DELTA_X_2
# RMS_DELTA_Y_2
# FIRST_NIGHT
# LAST_NIGHT
# NUM_NIGHT
# FIRST_EXPID
# LAST_EXPID
# NUM_EXPID
# FIRST_TILEID
# LAST_TILEID
# NUM_TILEID
# FIRST_FIBER_2
# LAST_FIBER_2
# NUM_FIBER_2
# B_DEPTH_2
# R_DEPTH_2
# Z_DEPTH_2
# subset_2

# %%
ff = fitsio.read('/project/projectdirs/desi/users/ajross/catalogs/SV/redshift_comps/test/'+str(td)+'_LRGzinfo.fits')

# %%
nl = []
for name in ff.dtype.names:
    nl.append(name)
f.keep_columns(nl)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-6ffa87a21802> in <module>
#       2 for name in ff.dtype.names:
#       3     nl.append(name)
# ----> 4 f.keep_columns(nl)
#
# /global/common/software/desi/cori/desiconda/20200801-1.4.0-spec/conda/lib/python3.8/site-packages/astropy/table/table.py in keep_columns(self, names)
#    2488         for name in names:
#    2489             if name not in self.columns:
# -> 2490                 raise KeyError(f"Column {name} does not exist")
#    2491
#    2492         remove = list(set(self.keys()) - set(names))
#
# KeyError: 'Column CHI2 does not exist'

# %%
tp = 'BGS_ANY'
f = fitsio.read('/project/projectdirs/desi/users/ajross/catalogs/SV/redshift_comps/blanc/v0/'+tp+'/alltiles_'+tp+'zinfo.fits') #fitsio *much* faster than using Table here
deep = f[f['subset']=='deep'] 
min_depth = np.max(deep['R_DEPTH'])/2
print(len(f),len(deep),min_depth)

#get list of truez in appropriate rows, matching Rongpu's definition for criteria required to allow truth determination
#rows without truth have z==0
mzl = np.zeros(len(f))
tids = np.unique(f['TARGETID'])
for iid in tids:
    sf = f['TARGETID'] == iid
    fi = f[sf]
    fd = fi[fi['subset']=='deep']
    mask = fd['FIBERSTATUS']==0 # Remove FIBERSTATUS!=0 fibers
    mask &= fd['ZWARN'] & 2**9==0 # Remove "no data" fibers
    mask &= fd['ZWARN']==0
    mask &= fd['R_DEPTH'] > min_depth
    mask &= fd['DELTACHI2'] > deep_dchi2
    if len(fd[mask]) > 0:
        mzl[sf] = fd['Z'][0]

w = mzl != 0
print(len(mzl[w]))
tf = Table(f)
tf['Z_TRUTH'] = mzl
masknight = tf['subset'] != 'deep'
masknight &= tf['subset'] != 'all'
masknight &= tf['Z_TRUTH'] != 0
masknight &= tf['FIBERSTATUS']==0
masknight &= tf['ZWARN'] & 2**9==0
tcomp = tf[masknight]
dz = tcomp['Z'] - tcomp['Z_TRUTH']
bz = abs(dz) > fail_threshold
bzz = bz & (tcomp['ZWARN'] != 0)
print('number, fraction of failures, fraction of failures with zwarn==0')
print(len(tcomp),len(tcomp[bz])/len(tcomp),len(tcomp[bzz])/len(tcomp))
rvals = np.unique(tcomp['R_DEPTH'])
ff = []
rv = []
nb = []
nt = []
for rval in rvals:
    ds = tcomp[tcomp['R_DEPTH']==rval]
    dz = ds['Z'] - ds['Z_TRUTH']
    bz = abs(dz) > fail_threshold
    if len(ds) > 30 and rval > mindepth:
        ff.append(len(ds[bz])/len(ds))
        nb.append(len(ds[bz]))
        nt.append(len(ds))
        rv.append(rval)
nt = np.array(nt)
nb = np.array(nb)
err = ((nt-nb)*(1.-(nt-nb)/nt))**.5/nt #binomial error formula, needs double-check
plt.errorbar(rv,ff,err,fmt='.')#,label=td)

#plt.legend()
plt.grid(alpha=0.5)
plt.xlabel('R_DEPTH effective exposure time')
plt.ylabel('failure fraction')
plt.show()
# Out:
# 161282 27705 9356.199974060059
# 4981
# number, fraction of failures, fraction of failures with zwarn==0
# 3362 0.04342653182629387 0.02558001189767995
